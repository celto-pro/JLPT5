# %%
# Importation
import jap_alphabet
import jap_JPTL5_80kanji
import global_functions
import exam

# %% [markdown]
# # JLPT 5: Evaluation
#
# This evaluation has five exercises.
# - First one is about japanese alphabet (10 points)
# - Second one is about kanji's translation -the 80 specific JLPT5 kanjis- (20 points)
# - Third one is similar. This time you need to find the kanjis from French + on/kun-yumi (20 points)
# - Fourth one is about vocabulary translation to french (25 points)
# - Last one is the opposite: French to japanese vocabulary (25 points)

# %%
exam.exam_JLPT5(4, 4, 12, 2)
# Out:
# The json's file will be updated, adding the following words:
# (ようか) le huit du mois, huit jours
# (ようふく) vêtement (de style occidental)
# (よっか) le quatre du mois, quatre jours
# (よぶ) appeler, inviter
# (よる | や) nuit, soir
# (りっぱ) magnifique, majestueux, superbe, louable
# (りょうり) cuisine; nourriture
# (れい) zéro; rien, vide
# (れんしゅう) entraînement, exercice
# (ろうか) couloir
# (わかい) jeune
# (わかる) comprendre, savoir, juger; découvrir
# (わたす) remettre (qqch à qq'un)
# (わたる) traverser
# (なかま) camarade, ami, associé, partenaire
# (くつじょく) humiliation, disgrâce
# (ねらう) viser
# (きず) blessure
# Do you want to proceed? Y/NY
# The json's file will be updated, adding the following words:
# あのやさしくてきれいな歌手は誰ですか
# このケーキはおいしそうですが、あまくなくて高かったです
# 料理が嫌いです
# Do you want to proceed? Y/NY
# \Sentences's exercise: Japanese's sentences to kun/on yumi + french.
#
#
#  Questions 1 to 10:
#
# ラーメンていしょくを四つください
# 何をしているのですか？
# 誰と行きましたか
# それは全く関係がない、全く違うことです | 全く別のことです
# 少し大きいですね
# このお茶は少し小さいですね
# アアー日本語が分かって来た
# ...

# %%
global_functions.show_score('JLPT5_fr_vocabulary.json', 'Score presentation')

# %%
global_functions.show_score('JLPT5_jap_vocabulary.json', 'Score presentation')
